# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread("cat.jpg")
cv2.imshow("first image", image)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("cat.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
upper = 150
lower = 400
crop_top = image[: ,left:right,:]
plt.figure(figsize=(5,5))
plt.imshow(cv2.cvtColor(crop_top, cv2.COLOR_BGR2GRAY))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 upper = 150
#       2 lower = 400
# ----> 3 crop_top = image[: ,left:right,:]
#       4 plt.figure(figsize=(5,5))
#       5 plt.imshow(cv2.cvtColor(crop_top, cv2.COLOR_BGR2GRAY))
#
# NameError: name 'left' is not defined

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("cat.jpg")

left = 150
right = 400

crop_top = image[:, left:right, :]

gray = cv2.cvtColor(crop_top, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(5, 5))
plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()
